# %%
def main():
    #Open the file or create new file if it doesn't exist.
    #f= open("name.txt","w+")
    #Add more content in file.
    f= open("name.txt","a")

#Write some line of data into file.
    for i in range(10):
     f.write("This is line " + str(i) + ("\r\n"))
    f.close()

# %%
main()

# %%
def main():
    f= open("name.txt","r")
    #opent the file backup and read the content.
    if f.mode=="r":
        contents =f.read()
        print(contents)

# %%
main()
# Out:
# This is line 0
#
# This is line 1
#
# This is line 2
#
# This is line 3
#
# This is line 4
#
# This is line 5
#
# This is line 6
#
# This is line 7
#
# This is line 8
#
# This is line 9
#
# This is line 0
#
# This is line 1
#
# This is line 2
#
# This is line 3
#
# This is line 4
#
# This is line 5
#
# This is line 6
#
# This is line 7
#
# This is line 8
#
# This is line 9
