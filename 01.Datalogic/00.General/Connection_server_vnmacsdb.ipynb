# %% [markdown]
# # Bai tap
# 1. ket noi srve
# 2. tim file
# 3. thực Thi print

# %%
# !pip install Flask-SQLAlchemy
# Out:
# Collecting Flask-SQLAlchemy
#   Downloading https://files.pythonhosted.org/packages/1e/65/226d95466c75e34e291a76890ed0e27af2e46ab913002847856f11d4d59d/Flask_SQLAlchemy-2.4.1-py2.py3-none-any.whl
# Requirement already satisfied: Flask>=0.10 in d:\03_anaconda3\lib\site-packages (from Flask-SQLAlchemy) (1.1.1)
# Requirement already satisfied: SQLAlchemy>=0.8.0 in d:\03_anaconda3\lib\site-packages (from Flask-SQLAlchemy) (1.3.9)
# Requirement already satisfied: Jinja2>=2.10.1 in d:\03_anaconda3\lib\site-packages (from Flask>=0.10->Flask-SQLAlchemy) (2.10.3)
# Requirement already satisfied: Werkzeug>=0.15 in d:\03_anaconda3\lib\site-packages (from Flask>=0.10->Flask-SQLAlchemy) (0.16.0)
# Requirement already satisfied: itsdangerous>=0.24 in d:\03_anaconda3\lib\site-packages (from Flask>=0.10->Flask-SQLAlchemy) (1.1.0)
# Requirement already satisfied: click>=5.1 in d:\03_anaconda3\lib\site-packages (from Flask>=0.10->Flask-SQLAlchemy) (7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\03_anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=0.10->Flask-SQLAlchemy) (1.1.1)
# Installing collected packages: Flask-SQLAlchemy
# Successfully installed Flask-SQLAlchemy-2.4.1

# %%
import pyodbc 
import numpy as np
import pandas as pd
#import sqlachademy
# conn = pyodbc.connect('Driver={SQL Server};'
#                       'Server=vnmacsdb;'
#                       'Database=acs ee;'a
#                       'Trusted_Connection=yes;')
conn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER=vnmacsdb;DATABASE=acs ee;UID=reports;PWD=reports')

# cursor = conn.cursor()
# cursor.execute('SELECT top 10 * FROM testlog order by test_date_time desc')

# for row in cursor:
#     print(row)
sql='SELECT top 10 * FROM testlog order by test_date_time desc'
data = pd.read_sql(sql,conn)
data
# Out:
#              ACS_Serial             SAP_Model               Station  \
# 0  G20A39005             QW2120-BKK1S          ZZGUNTEST4
# 1  G20AADSZO             700261002             ZZALIGN4
# 2  G20AAHATK             683930024             MAINBD3
# 3  G20AACNKH             740221602             34003500PERF1
# 4  G20AAGWTS             683930024             MAINBD4
# 5  G20AAHGLU             740258600             CRADLERADIOLINKi1
# 6  G20AACNKH             740221602             34003500PERF1
# 7  G20AADSZQ             700261002             ZZALIGN2
# 8  G20AACQRR             700034401             LTFOCUS5
# 9  G20AACNJR             740221602             34003500PERF1
#
#                                              Test_ID Pass_Fail FirstRun  \
# 0  ZZGUNTEST41/8/2020 3:58:37 PM                 ...       P         Y
# 1  ZZALIGN41/8/2020 3:59:00 PM                   ...       P         Y
# 2  MAINBD31/8/2020 3:55:52 PM                    ...       P         Y
# 3  34003500PERF11/8/2020 3:59:36 PM              ...       P         N
# 4  MAINBD41/8/2020 3:55:04 PM                    ...       P         Y
# 5  CRADLERADIOLINKi12020/01/08 15:59:20 PM-000   ...       P         Y
# 6  34003500PERF11/8/2020 3:59:29 PM              ...       F         Y
# 7  ZZALIGN21/8/2020 3:58:40 PM                   ...       P         Y
# 8  LTFOCUS51/8/2020 3:56:40 PM                   ...       P         Y
# 9  34003500PERF11/8/2020 3:57:35 PM              ...       P         N
#
#            Test_Date_Time  ACSEEMode      TL_ID       WorkCenter
# 0 2020-01-08 15:59:59.180          0  108455562       ZZGUNTEST4
# 1 2020-01-08 15:59:57.880          0  108455561         ZZALIGN4
# 2 2020-01-08 15:59:54.240          0  108455560   VNTESFUNTEST02
# 3 2020-01-08 15:59:53.960          0  108455559     MGL3435PERF1
# 4 2020-01-08 15:59:53.370          0  108455558   VNTESFUNTEST01
# 5 2020-01-08 15:59:50.343          0  108455557  CRADLERADIOLINK
# 6 2020-01-08 15:59:48.570          0  108455556     MGL3435PERF1
# 7 2020-01-08 15:59:44.863          0  108455555         ZZALIGN2
# 8 2020-01-08 15:59:38.653          0  108455554    VNFOCUS3233-1
# 9 2020-01-08 15:59:30.090          0  108455553     MGL3435PERF1
