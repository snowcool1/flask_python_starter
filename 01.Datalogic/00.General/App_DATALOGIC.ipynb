# %% [markdown]
# # Bai tap
# 1. ket noi srve
# 2. tim file
# 3. thực Thi print

# %%
import pyodbc 
import numpy as np
import pandas as pd
import sqlachademy
# conn = pyodbc.connect('Driver={SQL Server};'
#                       'Server=vnmacsdb;'
#                       'Database=acs ee;'a
#                       'Trusted_Connection=yes;')
conn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER=vnmacsdb;DATABASE=acs ee;UID=reports;PWD=reports')

# cursor = conn.cursor()
# cursor.execute('SELECT top 10 * FROM testlog order by test_date_time desc')

# for row in cursor:
#     print(row)
sql='SELECT top 10 * FROM testlog order by test_date_time desc'
data = pd.read_sql(sql,conn)
data
# Out:
#              ACS_Serial             SAP_Model               Station  \
# 0  G20AABASS             700261002             ZZALIGN4
# 1  G20AABOBO             683656013             VNPROGRAM07i1
# 2  G20AAAMUD             663494012             BSCAN2
# 3  G20AAAMPH             663494012             BSCAN15
# 4  G20A07623             QW2420-BKK1S          ZZGUNTEST3i1
# 5  G20A12326             TD1120-BK-90K1        MUSEOCONFIG61
# 6  G19NBJCYF             663107011             POSDREPAIR03i1
# 7  G19NBIJXA             684131073             3400PCBTEST1
# 8  G20A12386             TD1120-BK-90K1        ZZGUNTEST6
# 9  G20A12162             TD1120-BK-90K1        ZZGUNTEST5
#
#                                              Test_ID Pass_Fail FirstRun  \
# 0  ZZALIGN41/2/2020 9:02:00 PM                   ...       P         Y
# 1  VNPROGRAM07i12020/01/02 21:01:55 PM-000       ...       P         Y
# 2  BSCAN21/2/2020 9:02:16 PM                     ...       P         Y
# 3  BSCAN151/2/2020 9:02:06 PM                    ...       P         Y
# 4  ZZGUNTEST3i12020/01/02 20:59:55 PM-001        ...       P         N
# 5  MUSEOCONFIG611/2/2020 9:02:05 PM              ...       P         Y
# 6  POSDREPAIR03i12020/01/02 21:02:05 PM-000      ...       P         Y
# 7  3400PCBTEST1_VN3400BDTEST_01/02/2020 21:02:48 ...       P         Y
# 8  ZZGUNTEST61/2/2020 9:01:30 PM                 ...       P         Y
# 9  ZZGUNTEST51/2/2020 9:01:22 PM                 ...       P         Y
#
#            Test_Date_Time  ACSEEMode      TL_ID    WorkCenter
# 0 2020-01-02 21:03:03.480          0  108288736      ZZALIGN4
# 1 2020-01-02 21:03:03.237          0  108288735   VNPROGRAM07
# 2 2020-01-02 21:02:58.627          0  108288734      VNBSCAN2
# 3 2020-01-02 21:02:53.620          0  108288733      VNBSCAN1
# 4 2020-01-02 21:02:51.603          0  108288732    ZZGUNTEST3
# 5 2020-01-02 21:02:50.693          0  108288731  VNFFCSPARE02
# 6 2020-01-02 21:02:49.223          0  108288730          None
# 7 2020-01-02 21:02:48.613          0  108288729  VN3400BDTEST
# 8 2020-01-02 21:02:48.490          0  108288728    ZZGUNTEST6
# 9 2020-01-02 21:02:41.400          0  108288727    ZZGUNTEST5
