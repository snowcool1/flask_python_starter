# %%
import os
import shutil


shutil.copytree('D:\FRUlabel', 'C:\FRUlabelPNPC')
# shutil.copytree('baz', 'foo', dirs_exist_ok=True)
os.path.isfile('//vnmacsdb/bformats/FRUlabelPNPC/None.btw')
os.path.exists('//vnmacsdb/bformats/FRUlabelPNPC/')
# Out:
# 'C:\\FRUlabelPNPC'

# %%
import numpy as np  # Số
import pandas as pd # Data wrangling, Data Frame.
import streamlit as st
import pyodbc
import subprocess
import os 
from subprocess import Popen
import shutil


# testlabel ="300.btw"

Model_input = '890003434'

#-------------Connection Section-------------------


# def conn_server():
conn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER=vnmsrv601.dl.net\Siplace_2008R2EX;DATABASE=MobileDB;UID=Sa;PWD=Siplace.1')
sql=f"SELECT top 5 * FROM LabelcodeFruPP where Model ='{Model_input}'"
#print(sql)
df=pd.read_sql(sql,conn)
#     model ='890003434'
#print(conn,"Connection OK")   

if Model_input != '':
    if  len(df) > 0:        
        print('Result as below: ',df)               
    else:
        print('Model is not setup')
else:
    print('Please input model here !!!')

    
# # ----------- Showing Characteristic----------------------
# # c= '111' + '.btw'
# Label_name= df.loc [0, 'Characteristic'] 
# c=str(Label_name + '.btw')
# c=c.replace(" ","")
# print(c)
# btw = os.path.isfile(f"//vnmsrv601/DevelopSoftware/T01-Print Label/FRUlabel/" + c)
# print(btw)

# #Change dir to correct app path
# rootfolder="C:/Program Files (x86)/Seagull/BarTender Suite/BarTender"
# assert os.path.isdir(rootfolder)
# os.chdir(rootfolder)
# #Prepare path
# appname=fr'bartend.exe'
# btwfile=fr"C:\FRUlabelPNPC\ + {c}"  ##d \ slash forward for window

# if (btw == True):
#     #Run All wwith argument
#     subprocess.Popen([appname,btwfile,"/P","/X"])
# #     print('In nhé')        
#     # path = r"//vnmacsdb/bformats/FRUlabelPNPC/"
    
#     # print(dirs)
#     path = r"C:\FRUlabelPNPC" 
#     dirs = os.listdir(path)

#     for label in dirs:
#     #     print(label) 

#         if label != c:
#             if os.path.exists(r"C:\FRUlabelPNPC" == True):
#                 shutil.rmtree(r"C:\FRUlabelPNPC", ignore_errors=True)
#                 shutil.copytree('D:\FRUlabelPNPC', 'C:\FRUlabelPNPC')
#                 print('Xóa thư mục có sẵn')
#     #             break
#             else:
#                 shutil.copytree('D:\FRUlabelPNPC', 'C:\FRUlabelPNPC')
#                 print('copy from server')
#             #     print(dirs)
#         else:
#             print("in nhé")
#             break

    
# else:
#     print('The label is not setup')
 
    
    
    
    
    
#     ***********************************************************************
    
# # path = r"//vnmacsdb/bformats/FRUlabelPNPC/"
# path = r"C:\FRUlabelPNPC" 
# dirs = os.listdir(path)

# # print(dirs)

# for label in dirs:
# #     print(label) 
    
#     if label != testlabel:
#         if os.path.exists(r"C:\FRUlabelPNPC" == True):
#             shutil.rmtree(r"C:\FRUlabelPNPC", ignore_errors=True)
#             shutil.copytree('D:\FRUlabelPNPC', 'C:\FRUlabelPNPC')
#             print('Xóa thư mục có sẵn')
# #             break
#         else:
#             shutil.copytree('D:\FRUlabelPNPC', 'C:\FRUlabelPNPC')
#             print('copy from server')
#         #     print(dirs)
#     else:
#         print("in nhé")
#         break
# Out:
# Result as below:              Family                           Model  \
# 0  FRU-MGL32/33     890003434
#
#                                                  Des Characteristic PPorBuild  \
# 0  PART,LOAD CELL MOUNT,MGL93/94                 ...      None          PP
#
#   Irregular
# 0      None

# %%
import os
import shutil
import os
import shutil
import os.path

# # define the name of the directory to be created
# lb = "00.btw"
# path = f"C:/FRUlabelPNPC"
# if os.path.isfile('{lb}'):
#     print('in nhé')
# else:
#     shutil.copytree('\\\vnmacsdb\bformats\FRUlabelPNPC', 'C:\FRUlabelPNPC')
#     print('copy rồi, in nhé')

# # try:
# #     os.mkdir(path)
# # except OSError:
# #     print ("Creation of the directory %s failed" % path)
# # else:
# #     print ("Successfully created the directory %s " % path)
    
    
# # src= r'D:\FRUlabel'
# # dst = r'C:\FRUlabelPNPC'
# os.path.exists(r"C:\FRUlabelPNPC")
# Out:
# False

# %%
# #Check folder exist, if not create 
# if check_folderexist():
#     print('Có folder')
    
# else:
#     create_folder()
#     print('Tạo folder')
    
# #check file exist

# import subprocess
# import os 
# from subprocess import Popen
 
# #Change dir to correct app path
# rootfolder="C:/Program Files (x86)/Seagull/BarTender Suite/BarTender"
# assert os.path.isdir(rootfolder)
# os.chdir(rootfolder)
 
# #Prepare path
# appname=fr'bartend.exe'
# btwfile=r"C:\FRUlabelPNPC\500.btw" # d \ slash forward for window
 
# #Run All wwith argument
# subprocess.Popen([appname,btwfile,"/P","/X"])
# Out:
# Có folder
# File C:\FRUlabelPNPC\00.btw exist

# %%
#Đã ổn rồi

import os
import shutil
import os.path
import subprocess 
from subprocess import Popen

#***************************** Batender activate ********
# def batender_print():
#     #Change dir to correct app path
#     rootfolder="C:/Program Files (x86)/Seagull/BarTender Suite/BarTender"
#     assert os.path.isdir(rootfolder)

#     os.chdir(rootfolder)

#     #Prepare path
#     appname=fr'bartend.exe'
#     btwfile= os.path.join(filepath, filename)  #fullpath r"C:\FRUlabelPNPC\500.btw" # d \ slash forward for window

#     #Run All wwith argument
#     subprocess.Popen([appname,btwfile,"/P","/X"])

#***************************** Check Folder & create Folder********
# testlabel ="300.btw"
# path = r"//vnmacsdb/bformats/FRUlabelPNPC/"
source = 'D:\FRUlabelPNPC'
destination_local = 'C:\FRUlabelPNPC'
filepath = r'C:\FRUlabelPNPC'
filename = '500.btw'
# path = r"C:\FRUlabelPNPC" 

# print(dirs)

def check_folderexist(filepath):   #path="C:\FRUlabelPNPC"
    if os.path.exists(fr"{filepath}"):  #path
        return True
    
    else:
        return False
    
def create_folder():       #Lưu ý đổi local source to server.
    shutil.copytree(source, destination_local)

    
def check_fileexist(filepath,filename):    
    fullpath=os.path.join(filepath, filename)
    if os.path.isfile(fullpath):
#         bartend.exe /F=C:\FRUlabelPNPC\100.btw /P
#         bartend.exe /x /F=D:\FRUlabelPNPC\104.btw /P

#         batender_print()
        print (f"File {fullpath} exist")
        
        
    else:
        print ("Copy from server to local")
        shutil.rmtree(destination_local, ignore_errors=True)
        print('Xóa thư mục có sẵn')
        shutil.copytree(source, destination_local)
        print('In sau khi update') 
        
        
if check_folderexist(True):
    check_fileexist()
else:
    shutil.rmtree(destination_local, ignore_errors=True)#r
    shutil.copytree(source, destination_local)

dirs = os.listdir(filepath)
for file in dirs:
#     print(file)
    if check_fileexist(filepath,filename):        
        print ('in nhé')
        
    else:
        check_folderexist(filepath)
        break
        



    
# for label in dirs:
# #     print(label)     
#     if label == testlabel:
#         if check_folderexist():
# #             print(os.path.exists(r"C:\FRUlabelPNPC"))
# # #             shutil.rmtree(r"C:\FRUlabelPNPC", ignore_errors=True)
# #             print('Xóa thư mục có sẵn')
# #             shutil.copytree('D:\FRUlabelPNPC', 'C:\FRUlabelPNPC')
# #             print('In sau khi update') 
#             print("in nhé")
#             break
#         else:
#             shutil.copytree('D:\FRUlabelPNPC', 'C:\FRUlabelPNPC')
#             print('copy from server')
#         #     print(dirs)
#     else:
#         shutil.rmtree(r"C:\FRUlabelPNPC", ignore_errors=True)
#         print('Xóa thư mục có sẵn')
#         shutil.copytree('D:\FRUlabelPNPC', 'C:\FRUlabelPNPC')
#         print('In sau khi update') 
# #         print("in nhé")
# Out:
# File C:\FRUlabelPNPC\500.btw exist

# %%
### Saplink function

import pickle
import pandas as pd
import numpy as np
import copy
import time

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import roc_auc_score
import sqlalchemy
import pyodbc
   
def saplinkinfo_multi(material):
        
        import xml.etree.ElementTree as ET
        from urllib.request import urlopen
        from xml.etree.ElementTree import parse
        import time 
        import urllib.parse
        import asyncio
        start=time.time()
        
        def saplinkinfo_local(material='770112003'):
            import xml.etree.ElementTree as ET
            from urllib.request import urlopen
            from xml.etree.ElementTree import parse
            import time 
            import urllib.parse
            start=time.time()
        #     material='770112003'
            # tree = ET.parse('saplink.xml')
            tag=fr'''
            <Z_DMS_MATERIAL_INFO>
            <LANG>E</LANG>
            <WERKS>3400</WERKS>
            <VALIDON>12/31/9999</VALIDON>
            <MATNR>{material.strip().upper()}</MATNR>
            </Z_DMS_MATERIAL_INFO>
            '''
            encodetag=urllib.parse.quote_plus(tag)

            query='http://home/saplink/PRD/default.asp?XDoc='

            url =query+encodetag
#             print(url)

            var_url = urlopen(url)
            tree = parse(var_url)

            # tree = ET.parse(url)
            root = tree.getroot()
            root.tag
            print(root)
#             print(root.iter('DESCRIPTION').text)
            # for child in root:
            #     print(child.tag, child.attrib)

            # [elem.tag for elem in root.iter()]
            list_des=[]
            material_description=""
            for description in root.iter('ZDMSECO'):
                material_description=description.text
                for X2 in description.iter('CHGNUM'):
                    print(X2.text)
        #         print(description.text)
                list_des.append(material_description)
        #     print("run in seconds: %s" % str(time.time()-start))
            return list_des, material
        
    #     material='770112003'
        # tree = ET.parse('saplink.xml')
        list_name=[]
        for item in range(len(material)):
#             print(material[item])
            eng_item= (saplinkinfo_local(material[item]))[0]
#             print(eng_item)
            list_name.append(eng_item[0])
        eng_list=list_name
        return eng_list
df= saplinkinfo_multi(['890003434'])

df
# print('Print done')
# Out:
# <Element 'ROOT' at 0x000001A3CED729A8>
# 000000016469
# 000000021560
# [None]

# %%
# COnnect XML function
import xml.dom.minidom
from xml.dom import minidom
import xml.etree.ElementTree as ET



# parse an xml file by name
mydoc = minidom.parse('D:/02.Python/03.App_python/items.xml')
tree = ET.parse('D:/02.Python/03.App_python/items.xml')
# MATNR =  mydoc.getElementsBytagName("MATNR")
xpath = '*[attribute4="'  '"]'


# items = mydoc.SubElement('ROOT,DESCRIPTION')

# one specific item attribute
print('Item #2 attribute:')
print(mydoc.nodeName)
print(mydoc.firstChild.tagName)

for elem in tree.findall(".//*[@DESCRIPTION]"):
    elem.attrib["DESCRIPTION"] = "6"

# ET.dump(tree.getroot())

# for child in root:
#     print (child.tag, child.attrib)




# print(items[1].attributes['name'].value)

# # all item attributes
# print('\nAll attributes:')
# for elem in items:
#     print(elem.attributes['name'].value)

# # one specific item's data
# print('\nItem #2 data:')
# print(items[1].firstChild.data)
# print(items[1].childNodes[0].data)

# # all items data
# print('\nAll item data:')
# for elem in items:
#     print(elem.firstChild.data)
# Out:
# Item #2 attribute:
# #document
# ROOT
# LANG {'Class': 'I', 'Type': '130', 'DefinedSize': '1', 'Precision': '0', 'NumericScale': '0'}
# MATNR {'Class': 'I', 'Type': '130', 'DefinedSize': '18', 'Precision': '0', 'NumericScale': '0'}
# VALIDON {'Class': 'I', 'Type': '133', 'DefinedSize': '6', 'Precision': '0', 'NumericScale': '0'}
# WERKS {'Class': 'I', 'Type': '130', 'DefinedSize': '4', 'Precision': '0', 'NumericScale': '0'}
# DESCRIPTION {'Class': 'O', 'Type': '130', 'DefinedSize': '40', 'Precision': '0', 'NumericScale': '0'}
# LONGDESC {'Class': 'O', 'Type': '130', 'DefinedSize': '255', 'Precision': '0', 'NumericScale': '0'}
# RETURN_CODE {'Class': 'O', 'Type': '130', 'DefinedSize': '1', 'Precision': '0', 'NumericScale': '0'}
# REVISION {'Class': 'O', 'Type': '130', 'DefinedSize': '2', 'Precision': '0', 'NumericScale': '0'}
# ROHS {'Class': 'O', 'Type': '130', 'DefinedSize': '1', 'Precision': '0', 'NumericScale': '0'}
# VALIDFROM {'Class': 'O', 'Type': '133', 'DefinedSize': '6', 'Precision': '0', 'NumericScale': '0'}
# VALIDTO {'Class': 'O', 'Type': '133', 'DefinedSize': '6', 'Precision': '0', 'NumericScale': '0'}
# WEEE {'Class': 'O', 'Type': '130', 'DefinedSize': '1', 'Precision': '0', 'NumericScale': '0'}
# ZDMSAMPL {'Class': 'T'}
# ZDMSDIR {'Class': 'T'}
# ZDMSECO {'Class': 'T'}
# ZZMATLIST {'Class': 'T'}

# %%
import streamlit as st
import pandas as pd
import numpy as np
import subprocess
import os 
from subprocess import Popen

#Change dir to correct app path
rootfolder="C:/Program Files (x86)/Seagull/BarTender Suite/BarTender"
assert os.path.isdir(rootfolder)
os.chdir(rootfolder)
#Prepare path
appname=fr'bartend.exe'
# btwfile=fr"D:\FRUlabel\ + {c}"  ##d \ slash forward for window
btwfile = fr"C:\FRUlabelPNPC\104.btw" #/P

print(open(btwfile, "+"))

<?xml version="1.0" encoding="utf-8"?>
<XMLScript Version="2.0">
 <Command>
    <Print JobName="Job1">
     <Format>D:/FRUlabelPNPC/500.btw</Format>                 
    </Print> 
</Command>
</XMLScript>
